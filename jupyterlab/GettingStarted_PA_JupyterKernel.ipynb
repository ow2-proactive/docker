# %% [markdown]
# ### Print all available pragmas

# %%
#%help()

# %% [markdown]
# ### Connect to a ProActive server

# %%
#%connect(host=try.activeeon.com,login=YOUR_LOGIN,password=YOUR_PASSWORD)

# %% [markdown]
# ### Create a first python task

# %%
#%task(name=T1)
print("Hello from T1!")

# %% [markdown]
# ### Create a Bash task

# %%
#%task(name=T2,language=Linux_Bash)
echo "Hello from T2"

# %% [markdown]
# ### Create a Python task that depends on *T1* and *T2*

# %%
#%task(name=T3,dep=[T1,T2])
print("Hello from T3!")

# %% [markdown]
# ### Draw the constructed workflow

# %%
#%draw_job()

# %% [markdown]
# ### Submit the job to be executed

# %%
#%submit_job()

# %% [markdown]
# ### Print the outputs of the job

# %%
#%print_job_output(job_id=YOUR_JOB_ID)
